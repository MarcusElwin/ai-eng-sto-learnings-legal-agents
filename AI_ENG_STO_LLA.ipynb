# %% [markdown]
# # Learnings from building legal agents @Pocketlaw
#
#   <div style="background-color: #2c3033; padding: 15px; border-radius: 6px; margin-top: 30px; margin-bottom: 30px; border-left: 4px solid #ffd43b;">
#       <p style="color: #aaa; font-size: 14px; margin: 0;">
#           <strong style="color: white;">Disclaimer:</strong> All opinions expressed in this presentation are my own and do not represent the views of my employer.
#           This material is for educational purposes only.
#           <span style="float: right; color: #ffd43b;">© Marcus Elwin, 2025</span>
#       </p>
#   </div>
#
# ## AI Engineering Stockholm Meetup `2025-04-23`
#
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 30px;">
#       <h2 style="text-align: center; margin-bottom: 25px; border-bottom: 2px solid #ffd43b; padding-bottom: 15px;">
#           Table of Content
#       </h2>
#
# <div style="font-size: 18px; line-height: 1.6;">
#     <a href="#section1" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#         <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">1</span>
#         <span>Who am I? <span style="color: #aaa; font-size: 15px;">- Introduction and background</span></span>
#     </a>
#
# <a href="#section2" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">2</span>
#     <span>Who are Pocketlaw? <span style="color: #aaa; font-size: 15px;">- Company overview</span></span>
# </a>
#
# <a href="#section3" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">3</span>
#     <span>AI and Agents in the Legal Domain <span style="color: #aaa; font-size: 15px;">- Current applications</span></span>
# </a>
#
# <a href="#section4" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">4</span>
#     <span>A few learnings from working with Agents in Legal Tech <span style="color: #aaa; font-size: 15px;">- Key insights</span></span>
# </a>
#
# <a href="#section5" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">5</span>
#     <span>Conclusions <span style="color: #aaa; font-size: 15px;">- Summary and takeaways</span></span>
# </a>
#
# <a href="#section6" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">6</span>
#     <span>References <span style="color: #aaa; font-size: 15px;">- Sources and citations</span></span>
# </a>
# </div>
#   </div>
#
# Let's start shall we.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#  <a id="section1"></a>
# # 1. Who am I? 📖
#   <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; max-width: 1000px;">
#
#   <h2 style="font-size: 28px; margin-bottom: 20px;"><span style="color: yellow;">Hi</span> 👋🏽 I'm Marcus!</h2>
#
#    <h2 style="font-size: 22px; margin-bottom: 20px;"><span style="color: yellow;">Lead AI Engineer @Pocketlaw</span> </h2>
#
#   <div style="display: flex; align-items: flex-start; max-width: 1000px; margin-bottom: 30px;">
#       <div style="flex: 1; padding-right: 40px;">
#           <ul style="padding-left: 20px;">
#               <li style="margin-bottom: 15px;">Background in Computer Science & Machine Learning (KTH)</li>
#               <li style="margin-bottom: 15px;">7+ years of AI & ML experience in various roles and industries</li>
#               <li style="margin-bottom: 15px;">Worked with DS, ML, DL, now GenAI and a pit of product management</li>
#               <li style="margin-bottom: 15px;">Previously at Tink, ICA Gruppen AB & Nasdaq</li>
#               <li>Joined Pocketlaw Nov 23'</li>
#           </ul>
#       </div>
#       <div style="width: 300px; flex-shrink: 0;">
#           <img src="images/animeME.png" width="100%" />
#       </div>
#   </div>
#
#   <div style="display: flex; gap: 40px;">
#       <div style="text-align: center;">
#           <img src="images/blog_qr.png" width="150px" />
#           <p><strong>Personal Blog</strong></p>
#       </div>
#       <div style="text-align: center;">
#           <img src="images/linkedin_qr.png" width="150px" />
#           <p><strong>LinkedIn</strong></p>
#       </div>
#   </div>
#   </div>

# %% [markdown]
#  <a id="section2"></a>
# # 2. Who are Pocketlaw?

# %% [markdown]
# __TODO__

# %% [markdown]
#  <a id="section3"></a>
# # 3. AI and Agents in the Legal Domain

# %% [markdown]
# ## 3.1 AI in Legal domain - historical timeline
# To set the stage, let's start of with some key historical events for AI in the Legal domain:
#
# <div style="width: 100%; padding: 20px; background-color: #2c3033; color: white;">
# <h1 style="text-align: center; margin-bottom: 30px; color: white;">AI in Legal Domain - Historical Timeline</h1>
#
# <div style="max-width: 800px; margin: 0 auto; position: relative; min-height: 700px;">
#     <!-- Center line with fixed height -->
#     <div style="position: absolute; width: 4px; background-color: #555; height: 100%; left: 50%; margin-left: -2px;"></div>
#
# <!-- 1950s-1960s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1950s-1960s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>1950 - Turing test<sup>1</sup></li>
#                 <li>1956 - Dartmouth Conference<sup>2</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 1970s-1980s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1970s-1980s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>1970s: Expert systems in Law<sup>3</sup></li>
#             <li>1980: MYCIN inspires legal AI<sup>4</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
#
# <!-- 1990s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1990s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>1990s: NLP in legal document analysis<sup>5</sup></li>
#                 <li>1990s: Case based reasoning systems like HYPO<sup>6</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 2000s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2000s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>2000s: e-discovery introduced<sup>7</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
#
# <!-- 2010s -->
# <div style="position: relative; margin-bottom: 80px; height: 120px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2010s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>2011: IBM Watson wins Jeopardy<sup>8</sup></li>
#                 <li>2012: Ross Intelligence<sup>9</sup></li>
#                 <li>2016: Kira Systems<sup>10</sup></li>
#                 <li>2018: LawGeex outperforms human lawyers<sup>11</sup></li>
#                 <li>2018: Lex Machina & Premonition<sup>12</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 2020s -->
# <div style="position: relative; margin-bottom: 40px; height: 120px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2020s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>2020: GPT-3 released<sup>13</sup></li>
#             <li>2020: Pocketlaw founded<sup>14</sup></li>
#             <li>2022: ChatGPT released with legal Chatbots to follow<sup>15</sup></li>
#             <li>2023: Pocketlaw does AI pivot<sup>16</sup></li>
#             <li>2024+: AI in legal tech thrives with plethora of actors<sup>17</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
# </div>
#
# <p style="text-align: center; margin-top: 30px; color: #aaa; font-size: 0.8rem;">Numbers 1-17 represent citations/references to source materials</p>
# </div>

# %% [markdown]
# ## 3.2 Examples of Agentic use cases for Legal

# %% [markdown]
# ### AI  agent Overview
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">AI Agent Overview</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Simplified model of AI Agent, plenty out there
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Observe Environment
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Take actions to achive goals
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Loop until goals are achived
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - Overview.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ### AI Agent Example Use Case #1: Contract Review
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">Example of Contract Review Agent</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       User ask for feedback on a contract e.g. NDA
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Agent has memory from previous interactions
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans: clause analysis
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Uses various tools
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Recommend amendments to contract
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - CR.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ### AI Agent Example Use Case #2: Legal Research
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">Example of Legal Research Agent</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       User ask for particular research query
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Agent has memory from previous interactions
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans: clause analysis
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Uses various tools i.e. internet or legal databases (similar to deep research mode)
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Presents findigns
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - LS.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ## 3.3 Why are Agents and Agentic Workflows of interest for Legal Tech?

# %% [markdown]
# __TODO__

# %% [markdown]
# <a id="section4"></a>
# # 4. A few learnings from working with Agents in Legal Tech 🤖
# Which may or may not be applicable to other domains. Turns out all of us are doing quite similar things in this GenAI era...
#
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 0 0 10px 10px; margin-bottom: 30px;">
#   <p style="margin-bottom: 20px; line-height: 1.6;">
#     After working with legal tech, LLMs and now Agents for the past 18 months I have seen some learnings.
#     Some of these are not unique to me or my experiences. Anyhow, some learnings in no inherent ordering:
#   </p>
#
#   <div style="margin: 30px 0;">
#     <div style="display: flex; align-items: center; margin-bottom: 20px;">
#       <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">1</span>
#       <span style="flex: 1;">
#         Even if Agents are cool, they don't solve all problems<br>
#         <small style="color: #ccc;">
#           Agents excel at orchestrating tasks but may not outperform specialized models, or stacked chains of LLM calls or rule‑based systems for narrow jobs or tasks.
#         </small>
#       </span>
#     </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">2</span>
#     <span style="flex: 1;">
#       Choose what framework or library solves your <b>Use Case the best</b><br>
#       <small style="color: #ccc;">
#         Evaluate trade‑offs in features, integrations, and community support before committing to one solution.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">3</span>
#     <span style="flex: 1;">
#       Be able to quickly iterate on different models for different parts of your flow<br>
#       <small style="color: #ccc;">
#         Swap models in and out to optimize for cost, latency, and accuracy at each step of your agent pipeline.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">4</span>
#     <span style="flex: 1;">
#       Start Simple i.e. 1 agent or agentic flow and extend when necessary<br>
#       <small style="color: #ccc;">
#         Begin with a minimal proof‑of‑concept and add complexity only when you’ve validated real user value.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">5</span>
#     <span style="flex: 1;">
#       Use a tracing solution, you will need it<br>
#       <small style="color: #ccc;">
#         Capture each prompt, tool call, and response to debug issues and maintain an audit trail.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">6</span>
#     <span style="flex: 1;">
#       Make sure to track costs, Agent loops can be expensive<br>
#       <small style="color: #ccc;">
#         Monitor API usage and loop iterations to prevent unexpected billing spikes.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">7</span>
#     <span style="flex: 1;">
#       Give control to the end-user i.e. HIL or <i>human-in-the-loop</i><br>
#       <small style="color: #ccc;">
#         Allow humans to intervene, review, and override agent decisions at critical steps.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">8</span>
#     <span style="flex: 1;">
#       Always ground your Agent results, end-users in this case lawyers will always fact check<br>
#       <small style="color: #ccc;">
#         Provide source snippets and citations so lawyers can verify and trust AI outputs.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">9</span>
#     <span style="flex: 1;">
#       Prioritize ethical guardrails and explainability for regulatory compliance<br>
#       <small style="color: #ccc;">
#         Build in audit logs, human‑escalation triggers and clear rationales so every decision is transparent and GDPR‑/industry‑ready.
#       </small>
#     </span>
#   </div>
#
#   <div style="display: flex; align-items: center; margin-bottom: 20px;">
#     <span style="background-color: #444; border-radius: 50%; min-width: 40px; height: 40px; display: inline-flex; justify-content: center; align-items: center; margin-right: 20px; color: #ffd43b; font-weight: bold;">10</span>
#     <span style="flex: 1;">
#       Implement continuous monitoring and feedback‑driven iteration<br>
#       <small style="color: #ccc;">
#         Define clear KPIs (accuracy, cost, user satisfaction), collect metrics from each run, and regularly refine prompts, tools, and models with your legal team.
#       </small>
#     </span>
#   </div>
#   </div>
#
#   <div style="background-color: #3a3f45; padding: 20px; border-radius: 6px; margin-top: 30px; border-left: 4px solid #ffd43b;">
#     <p style="margin: 0;">
#       To exemplify some of these learnings we will show examples on a Fictional NDA contract with a fictional NDA policy document or playbook to demonstrate the Contract Review Agent flow.
#     </p>
#   </div>
# </div>

# %% [markdown]
# Load necessary libraries i.e. `langchain_openai` and `langchain_google_genai`

# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_google_vertexai import ChatVertexAI
from langchain_google_genai import ChatGoogleGenerativeAI
from utils import load_markdown_file, display_sample, display_formatted_sample

load_dotenv()
# Out:
# True

# %%
# Load the NDA files

from pathlib import Path
data_dir = Path("data")
sample_nda = load_markdown_file(data_dir / "sample_nda.md")
complex_nda = load_markdown_file(data_dir / "complex_nda.md")
nda_policy = load_markdown_file(data_dir / "nda_policy.md")

# %%
display_formatted_sample(sample_nda, "Sample NDA (First 10 lines)")
display_formatted_sample(complex_nda, "Complex NDA (First 10 lines)")
display_formatted_sample(nda_policy, "NDA Policy (First 10 lines)")
# Out:
#     <div style="background-color: #2c3033; color: white; padding: 15px; border-radius: 6px; margin-bottom: 20px;">
#         <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 5px;">Sample NDA (First 10 lines)</h3>
#         <pre style="background-color: #3a3f45; padding: 10px; border-radius: 4px; white-space: pre-wrap;"># MUTUAL NON-DISCLOSURE AGREEMENT
#
# THIS MUTUAL NON-DISCLOSURE AGREEMENT (the "Agreement") is made and entered into as of May 15, 2025 (the "Effective Date") by and between:
#
# **ACME CORPORATION**, a corporation organized and existing under the laws of Delaware, with its principal place of business at 123 Main Street, San Francisco, CA 94105 ("ACME")
#
# and
#
# **TECH INNOVATIONS INC.**, a corporation organized and existing under the laws of California, with its principal place of business at 456 Innovation Way, Palo Alto, CA 94301 ("TECH")
#
#         ...</pre>
#         <p style="color: #aaa; margin-top: 10px; font-size: 0.9em;">
# ...

# %% [markdown]
# Setup chat models in this case `gpt-4.1` and `gemini-2.5-flash`

# %%
llm_openai = ChatOpenAI(
    model="gpt-4.1",
    temperature=0
)

# %%
llm_google = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-preview-04-17",
    temperature=0,
)

# %% [markdown]
# ## 4.1.1 Even if Agents are cool, they don't solve all problems
# One common use case for when people are using LLM or GenAI is to extract key information from documents or other sources. Turns out that LLMs are quite good at doing this with some pre-defined schemas and domain instructions in prompts.
#
# Using an Agent to do this would be a bit overkill... but completly doable. In this example we will use `.withStructuredOutput` using Langchain and corresponding `pydantic` models vs using an agent using `pydantic-ai`.

# %% [markdown]
# We define the following model in `model.py`
#
# ```python
#   class ContractMetadata(BaseModel):
#       """Metadata extracted from a legal contract document"""
#
#       parties: List[Party] = Field(
#           description="List of all parties involved in the contract"
#       )
#
#       notice_date: Optional[DateInfo] = Field(
#           None,
#           description="Date by which notice must be given"
#       )
#
#       termination_date: Optional[DateInfo] = Field(
#           None,
#           description="Date when the contract terminates"
#       )
#
#       contract_value: Optional[ContractValue] = Field(
#           None,
#           description="Monetary value of the contract"
#       )
#
#       personal_data: Optional[PersonalDataInfo] = Field(
#           None,
#           description="Information about personal data processing in the contract"
#       )
# ```
#
# Normally you have much more entities to extract, but here we have a few to show case the flow.

# %%
from models import ContractMetadata
from prompts import get_legal_metadata_extraction_prompt

ner_prompt = get_legal_metadata_extraction_prompt()

# %% [markdown]
# Below is the prompt as we use langchain, a lot of extra stuff is added

# %%
from devtools import pprint

pprint(ner_prompt)
# Out:
# ChatPromptTemplate(
#     input_variables=[
#         'chat_history',
#         'contract_text',
#         'schema_str',
#     ],
#     input_types={
#         'chat_history': (
#             list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')],
#             typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')],
#             typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')],
#             typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')],
#             typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')],
#             typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')],
#             typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')],
#             typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')],
# ...

# %% [markdown]
# Next we define the structured llms using `.with_structured_output(...)` and the `ContractMetadata` schema

# %%
structured_llm_openai = llm_openai.with_structured_output(ContractMetadata)
structured_llm_google = llm_google.with_structured_output(ContractMetadata)

# %% [markdown]
# Next we define the `chains` to use our prompt for `NER`

# %%
chain_openai = ner_prompt | structured_llm_openai
chain_google = ner_prompt | structured_llm_google

# %%
import json

# extract metadata from the sample NDA
metadata_openai = chain_openai.invoke({
    "schema_str": json.dumps(ContractMetadata.model_json_schema(), indent=2),
    "contract_text": sample_nda, 
    "chat_history": []}
)

# %%
pprint(metadata_openai)
# Out:
# ContractMetadata(
#     parties=[
#         Party(
#             name='ACME CORPORATION',
#             role=None,
#             clause_reference='Preamble, Signature Block',
#         ),
#         Party(
#             name='TECH INNOVATIONS INC.',
#             role=None,
#             clause_reference='Preamble, Signature Block',
#         ),
#     ],
#     notice_date=DateInfo(
#         date='30 days prior written notice',
#         clause_reference='Section 5.2',
#     ),
#     termination_date=DateInfo(
#         date='2028-05-15',
#         clause_reference='Section 5.1',
#     ),
#     contract_value=ContractValue(
#         amount='no monetary value',
#         currency=None,
#         clause_reference='Section 9',
#     ),
#     personal_data=PersonalDataInfo(
#         processing='Yes',
#         details=(
#             'In the event that Confidential Information includes personal data as defined under applicable data protec'
# ...

# %%
# extract metadata from the sample NDA
metadata_google = chain_google.invoke({
    "schema_str": json.dumps(ContractMetadata.model_json_schema(), indent=2),
    "contract_text": sample_nda, 
    "chat_history": []}
)

# %%
pprint(metadata_google)
# Out:
# ContractMetadata(
#     parties=[
#         Party(
#             name='ACME CORPORATION',
#             role='Party',
#             clause_reference='introductory section',
#         ),
#         Party(
#             name='TECH INNOVATIONS INC.',
#             role='Party',
#             clause_reference='introductory section',
#         ),
#     ],
#     notice_date=DateInfo(
#         date='thirty (30) days prior written notice',
#         clause_reference='Section 5.2',
#     ),
#     termination_date=DateInfo(
#         date='2028-05-15',
#         clause_reference='Section 5.1',
#     ),
#     contract_value=ContractValue(
#         amount='no monetary value',
#         currency=None,
#         clause_reference='Section 9',
#     ),
#     personal_data=PersonalDataInfo(
#         processing='Yes',
#         details=(
#             'Personal data may be included in Confidential Information and can only be processed for the Purpose of th'
# ...

# %% [markdown]
# As you can see not perfectly accurate, but it does a good job of extracting the metadata from the NDA. The metadata is not perfect, but it is a good start. The model is able to extract the key entities and their values from the NDA.
#
# What we can see here is a clear need for a calculator tool for date arithmetic and potential the `ContractValue`. Let's see how an agent would do.

# %% [markdown]
# `pydantic-ai` is a newer framework but has a more pythonic approach in this framework an `Agent` is basically a `container` for the following, see more [here](https://ai.pydantic.dev/agents/):
#
#  <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 20px;">
#       <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 10px; margin-bottom: 20px;">Agent Components</h3>
#
# <table style="width: 100%; border-collapse: collapse;">
#     <thead>
#         <tr style="background-color: #3a3f45; text-align: left;">
#             <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Component</th>
#             <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Description</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 15px; font-weight: bold;">System prompt(s)</td>
#             <td style="padding: 12px 15px;">A set of instructions for the LLM written by the developer.</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444; background-color: #343a40;">
#             <td style="padding: 12px 15px; font-weight: bold;">Function tool(s)</td>
#             <td style="padding: 12px 15px;">Functions that the LLM may call to get information while generating a response.</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 15px; font-weight: bold;">Structured output type</td>
#             <td style="padding: 12px 15px;">The structured datatype the LLM must return at the end of a run, if specified.</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444; background-color: #343a40;">
#             <td style="padding: 12px 15px; font-weight: bold;">Dependency type constraint</td>
#             <td style="padding: 12px 15px;">System prompt functions, tools, and output validators may all use dependencies when they're run.</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 15px; font-weight: bold;">LLM model</td>
#             <td style="padding: 12px 15px;">Optional default LLM model associated with the agent. Can also be specified when running the agent.</td>
#         </tr>
#         <tr>
#             <td style="padding: 12px 15px; font-weight: bold;">Model Settings</td>
#             <td style="padding: 12px 15px;">Optional default model settings to help fine tune requests. Can also be specified when running the agent.</td>
#         </tr>
#     </tbody>
# </table>
#   </div>

# %%
# get prompts to pydantic
prompts = ner_prompt.format_messages(
    schema_str=json.dumps(ContractMetadata.model_json_schema(), indent=2),
    contract_text=sample_nda,
    chat_history=[],
)

# %%
system, human = prompts[0].content, prompts[1].content

# %%
from pydantic_ai import Agent

openai_agent = Agent(
    model='openai:gpt-4.1', 
    system=system,
    human=human,
    temperature=0, 
    verbose=True, 
    output_type=ContractMetadata,
    instrument=True
    )

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
pprint(openai_agent.run_sync(sample_nda))
# Out:
# AgentRunResult(
#     output=ContractMetadata(
#         parties=[
#             Party(
#                 name='ACME CORPORATION',
#                 role='Party',
#                 clause_reference='Preamble, signature block',
#             ),
#             Party(
#                 name='TECH INNOVATIONS INC.',
#                 role='Party',
#                 clause_reference='Preamble, signature block',
#             ),
#         ],
#         notice_date=DateInfo(
#             date='Thirty (30) days prior written notice',
#             clause_reference='Section 5.2',
#         ),
#         termination_date=DateInfo(
#             date='May 15, 2028 (three years from Effective Date, unless earlier terminated)',
#             clause_reference='Section 5.1',
#         ),
#         contract_value=ContractValue(
#             amount='0',
#             currency=None,
#             clause_reference='Section 9',
#         ),
#         personal_data=PersonalDataInfo(
# ...

# %% [markdown]
# Finally, let's try to add some tools to help the agent here

# %%
from dataclasses import dataclass
from typing import Optional

# Dependencies class for your agent
@dataclass
class ContractDeps:
    effective_date: Optional[str] = None  # The effective date of the contract

# %%
from pydantic_ai import RunContext

# Add calculator tool
@openai_agent.tool
async def calculator(ctx: RunContext[ContractDeps], expression: str) -> float:
    """Calculate the result of a mathematical expression.
    
    Args:
        ctx: The context with dependencies
        expression: Mathematical expression to evaluate (e.g., "2 + 3 * 4")
    """
    # Safety check for allowed characters
    allowed_chars = set("0123456789+-*/() .")
    if not all(c in allowed_chars for c in expression):
        raise ValueError(f"Invalid characters in expression: {expression}")

    try:
        return eval(expression)
    except Exception as e:
        return f"Error: {str(e)}"

# %%
import re
from datetime import datetime, timedelta

# Add date calculator tool
@openai_agent.tool
async def date_calculator(
    ctx: RunContext[ContractDeps], 
    operation: str,
    date_text: str,
    value: Optional[int] = None,
    unit: Optional[str] = None
) -> str:
    """Calculate, parse, or manipulate dates.
    
    Args:
        ctx: The context with dependencies
        operation: Operation to perform (parse, add, subtract)
        date_text: Text description of a date or date in ISO format
        value: Optional value for add/subtract operations
        unit: Optional unit for add/subtract operations (days, months, years)
    """
    # Get reference date from dependencies if available
    reference_date = ctx.deps.effective_date
    if reference_date is None:
        # Default to today if no effective date is provided
        reference_date = datetime.now().strftime("%Y-%m-%d")

    # Parse the reference date
    try:
        ref_date = datetime.strptime(reference_date, "%Y-%m-%d")
    except ValueError:
        return f"Error: Invalid reference date {reference_date}"

    # Handle different operations
    if operation.lower() == "parse":
        # Check if already in ISO format
        iso_pattern = r"^\d{4}-\d{2}-\d{2}$"
        if re.match(iso_pattern, date_text):
            return date_text

        # Try common date formats
        date_formats = ["%B %d, %Y", "%d %B %Y", "%B %d %Y", "%m/%d/%Y", "%d/%m/%Y"]
        for fmt in date_formats:
            try:
                date_obj = datetime.strptime(date_text, fmt)
                return date_obj.strftime("%Y-%m-%d")
            except ValueError:
                continue

        # Handle relative dates
        years_match = re.search(r"(\d+)\s+year", date_text.lower())
        months_match = re.search(r"(\d+)\s+month", date_text.lower())
        days_match = re.search(r"(\d+)\s+day", date_text.lower())

        if years_match or months_match or days_match:
            result_date = ref_date

            if years_match:
                years = int(years_match.group(1))
                result_date = result_date.replace(year=result_date.year + years)

            if months_match:
                months = int(months_match.group(1))
                new_month = result_date.month + months
                new_year = result_date.year + (new_month - 1) // 12
                new_month = ((new_month - 1) % 12) + 1
                result_date = result_date.replace(year=new_year, month=new_month)

            if days_match:
                days = int(days_match.group(1))
                result_date += timedelta(days=days)

            return result_date.strftime("%Y-%m-%d")

        # If we can't parse it, return the original
        return date_text

    elif operation.lower() in ["add", "subtract"]:
        # First parse the date_text if not already in ISO format
        if not re.match(iso_pattern, date_text):
            for fmt in ["%B %d, %Y", "%d %B %Y", "%B %d %Y", "%m/%d/%Y", "%d/%m/%Y"]:
                try:
                    date_obj = datetime.strptime(date_text, fmt)
                    date_text = date_obj.strftime("%Y-%m-%d")
                    break
                except ValueError:
                    continue

        # If we have a date in ISO format, do the calculation
        if re.match(iso_pattern, date_text):
            try:
                date_obj = datetime.strptime(date_text, "%Y-%m-%d")
            except ValueError:
                return f"Error: Invalid date format {date_text}"
        else:
            # Use reference date if date_text couldn't be parsed
            date_obj = ref_date

        # Check required parameters
        if value is None or unit is None:
            return "Error: Both value and unit are required for add/subtract operations"

        # Perform the calculation
        if operation.lower() == "add":
            if unit.lower() in ["day", "days"]:
                result_date = date_obj + timedelta(days=value)
            elif unit.lower() in ["month", "months"]:
                new_month = date_obj.month + value
                new_year = date_obj.year + (new_month - 1) // 12
                new_month = ((new_month - 1) % 12) + 1
                result_date = date_obj.replace(year=new_year, month=new_month)
            elif unit.lower() in ["year", "years"]:
                result_date = date_obj.replace(year=date_obj.year + value)
            else:
                return f"Error: Unknown unit {unit}"
        else:  # subtract
            if unit.lower() in ["day", "days"]:
                result_date = date_obj - timedelta(days=value)
            elif unit.lower() in ["month", "months"]:
                new_month = date_obj.month - value
                new_year = date_obj.year
                while new_month <= 0:
                    new_month += 12
                    new_year -= 1
                result_date = date_obj.replace(year=new_year, month=new_month)
            elif unit.lower() in ["year", "years"]:
                result_date = date_obj.replace(year=date_obj.year - value)
            else:
                return f"Error: Unknown unit {unit}"

        return result_date.strftime("%Y-%m-%d")

    else:
        return f"Error: Unknown operation {operation}"

# %%
pprint(openai_agent.run_sync(
    sample_nda,
    deps=ContractDeps(effective_date="2023-10-01")
))
# Out:
# AgentRunResult(
#     output=ContractMetadata(
#         parties=[
#             Party(
#                 name='ACME CORPORATION',
#                 role=None,
#                 clause_reference=None,
#             ),
#             Party(
#                 name='TECH INNOVATIONS INC.',
#                 role=None,
#                 clause_reference=None,
#             ),
#         ],
#         notice_date=DateInfo(
#             date='30 days prior written notice',
#             clause_reference='5.2',
#         ),
#         termination_date=DateInfo(
#             date='May 15, 2028 or earlier if terminated by notice',
#             clause_reference='5.1',
#         ),
#         contract_value=ContractValue(
#             amount='0',
#             currency='USD',
#             clause_reference='9',
#         ),
#         personal_data=PersonalDataInfo(
#             processing='Yes',
#             details=(
# ...

# %% [markdown]
#   ## 4.1.2 Choose what framework or library solves your Use Case the best
#
#   There is a multitude of frameworks and approaches for building AI agents:
#
#   <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 20px;">
#       <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 10px; margin-bottom: 20px;">Popular Agent
#   Frameworks</h3>
#       <ul style="padding-left: 25px;">
#           <li style="margin-bottom: 12px;"><b>LangGraph/LangChain</b> - Graph-based workflow engine with extensive
#   integrations</li>
#           <li style="margin-bottom: 12px;"><b>Pydantic-AI</b> - Python-native approach leveraging type hinting and Pydantic
#   schemas</li>
#           <li style="margin-bottom: 12px;"><b>CrewAI</b> - Multi-agent orchestration with role-based agents</li>
#           <li style="margin-bottom: 12px;"><b>OpenAI Assistants API</b> - Managed solution with built-in capabilities</li>
#           <li style="margin-bottom: 12px;"><b>Anthropic Claude SDK</b> - Agent and tools tailored to Claude's capabilities</li>
#           <li style="margin-bottom: 12px;"><b>Mastra AI</b> - Enterprise-focused agent framework with monitoring tools</li>
#           <li style="margin-bottom: 12px;"><b>Custom Approaches</b> - DIY loops and orchestration with direct API calls</li>
#       </ul>
#
# <p style="margin-top: 20px; margin-bottom: 20px;">My perspective: <i>Use what makes the most sense for your product and team
# - resist framework hype.</i></p>
#
# <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 10px; margin: 20px 0;">Frameworks vs. Custom
# Solutions</h3>
#
# <table style="width: 100%; border-collapse: collapse; margin-top: 20px;">
#     <thead>
#         <tr style="background-color: #3a3f45; text-align: left;">
#             <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Approach</th>
#             <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Pros</th>
#             <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Cons</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 15px; font-weight: bold; vertical-align: top;">Framework-based<br>(LangGraph, CrewAI,
# etc.)</td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Quick time-to-market<br>
#                 • Community support<br>
#                 • Built-in abstractions<br>
#                 • Ready-made integrations<br>
#                 • Standardized testing patterns
#             </td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Black-box behavior<br>
#                 • Framework lock-in<br>
#                 • Overhead for simple use cases<br>
#                 • Version dependency risks<br>
#                 • May not fit all use cases
#             </td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444; background-color: #343a40;">
#             <td style="padding: 12px 15px; font-weight: bold; vertical-align: top;">Custom Solution<br>(Direct API
# calls)</td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Complete control<br>
#                 • No external dependencies<br>
#                 • Lightweight implementation<br>
#                 • Tailored to specific needs<br>
#                 • Easier debugging
#             </td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Higher development effort<br>
#                 • Reinventing the wheel<br>
#                 • Maintenance burden<br>
#                 • Missing optimizations<br>
#                 • Limited community support
#             </td>
#         </tr>
#         <tr>
#             <td style="padding: 12px 15px; font-weight: bold; vertical-align: top;">Hybrid<br>(Light wrappers)</td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Balance of control and speed<br>
#                 • Focused abstractions<br>
#                 • Easier switching between models<br>
#                 • Selective use of components
#             </td>
#             <td style="padding: 12px 15px; vertical-align: top;">
#                 • Requires careful architecture<br>
#                 • Integration complexity<br>
#                 • Potential inconsistencies<br>
#                 • Requires stronger team skills
#             </td>
#         </tr>
#     </tbody>
# </table>
#
# <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; margin-top: 20px; border-left: 4px solid
# #ffd43b;">
#     <p style="margin: 0;"><b>Legal tech insight:</b> In legal applications, reliability and explainability often outweigh
# bleeding-edge features. Choose frameworks that prioritize stability, auditability, and clear execution paths.</p>
# </div>
# </div>
#
#    <div style="background-color: #2c3033; color: white; padding: 20px; border-radius: 6px; margin-top: 15px; margin-bottom: 15px;
#   border-left: 4px solid #ff6b6b;">
#       <p style="margin: 0 0 15px 0; font-style: italic;">
#           <span style="color: #ff6b6b; font-weight: bold;">Fun side note:</span> There's some online beef between LangChain,
#   OpenAI, and Pydantic-AI based on a recent <a
#   href="https://cdn.openai.com/business-guides-and-resources/a-practical-guide-to-building-agents.pdf" style="color:
#   #ff9e7d;">OpenAI guide to building agents</a> that sparked a Twitter/X debate about framework approaches.
#       </p>
#
# <div style="text-align: center; margin-top: 15px;">
#     <img src="images/framework-beef.png" width="450px" style="border-radius: 6px; box-shadow: 0 4px 8px rgba(0,0,0,0.4);
#   max-width: 100%;" />
#       </div>
#   </div>

# %% [markdown]
# ## 4.1.3 Be able to quickly iterate on different models for different parts of your flow
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 20px;">
# <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 10px; margin-bottom: 20px;">Model Experimentation
# & Iteration</h3>
#
# <p>LLM proxies and management layers have become essential tools in the agent development workflow:</p>
#
# <div style="display: flex; margin: 25px 0; gap: 30px;">
# <div style="flex: 1; background-color: #3a3f45; padding: 20px; border-radius: 6px; border-left: 4px solid #ffd43b;">
#     <h4 style="margin-top: 0; color: #ffd43b;">LLM Proxies</h4>
#     <ul style="padding-left: 20px;">
#         <li style="margin-bottom: 8px;"><b>LiteLLM</b> - Open-source library providing unified interface</li>
#         <li style="margin-bottom: 8px;"><b>Portkey</b> - Enterprise LLM gateway with observability</li>
#         <li style="margin-bottom: 8px;"><b>Langfuse</b> - Tracing and analytics platform</li>
#         <li style="margin-bottom: 8px;"><b>Parea AI</b> - Model evaluation and testing platform</li>
#     </ul>
# </div>
#
# <div style="flex: 1; background-color: #3a3f45; padding: 20px; border-radius: 6px; border-left: 4px solid #ffd43b;">
#     <h4 style="margin-top: 0; color: #ffd43b;">Benefits for Agent Development</h4>
#     <ul style="padding-left: 20px;">
#         <li style="margin-bottom: 8px;">Single API integration pattern</li>
#         <li style="margin-bottom: 8px;">Simplified A/B testing of models</li>
#         <li style="margin-bottom: 8px;">Performance and cost tracking</li>
#         <li style="margin-bottom: 8px;">Fallback handling for reliability</li>
#     </ul>
# </div>
# </div>
#
# <p>The unified API approach (typically following OpenAI's patterns) enables rapid model swapping while maintaining
# consistent code.</p>
#
# <div style="background-color: #3a3f45; padding: 20px; border-radius: 6px; margin: 25px 0; border-left: 4px solid #00c08b;">
# <h4 style="margin-top: 0; color: #00c08b;">Strategic Model Selection in Agent Architecture</h4>
# <table style="width: 100%; border-collapse: collapse; margin-top: 15px;">
#     <thead>
#         <tr style="border-bottom: 1px solid #555;">
#             <th style="padding: 8px; text-align: left; color: #ddd;">Component</th>
#             <th style="padding: 8px; text-align: left; color: #ddd;">Recommended Models</th>
#             <th style="padding: 8px; text-align: left; color: #ddd;">Key Considerations</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 8px; vertical-align: top;"><b>Planning & Orchestration</b></td>
#             <td style="padding: 12px 8px; vertical-align: top;">Mistral Small, Claude Haiku 3.5, GPT-4.1-mini</td>
#             <td style="padding: 12px 8px; vertical-align: top;">Low latency, reliable function calling, cost
# efficiency</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 8px; vertical-align: top;"><b>Reasoning & Analysis</b></td>
#             <td style="padding: 12px 8px; vertical-align: top;">Claude Sonnet 3.7, GPT-4.1, Gemini 2.5</td>
#             <td style="padding: 12px 8px; vertical-align: top;">Depth of reasoning, contextual understanding,
# specialized knowledge</td>
#         </tr>
#         <tr style="border-bottom: 1px solid #444;">
#             <td style="padding: 12px 8px; vertical-align: top;"><b>Tool Execution</b></td>
#             <td style="padding: 12px 8px; vertical-align: top;">Claude 3.7 Sonnet, GPT-4o-min, Gemini 2.5 Flash</td>
#             <td style="padding: 12px 8px; vertical-align: top;">Balance of speed and context understanding</td>
#         </tr>
#         <tr>
#             <td style="padding: 12px 8px; vertical-align: top;"><b>Final Response</b></td>
#             <td style="padding: 12px 8px; vertical-align: top;">Domain-specific fine-tuned models</td>
#             <td style="padding: 12px 8px; vertical-align: top;">Tone consistency, domain expertise, output
# formatting</td>
#         </tr>
#     </tbody>
# </table>
# </div>
#
# <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; margin-top: 20px; border-left: 4px solid
# #ffd43b;">
# <p style="margin: 0;"><b>Legal tech insight:</b> In legal applications, dedicated evaluation frameworks testing for
# legal accuracy, hallucination detection, and citation verification become critical parts of the model selection process.</p>
# </div>
# </div>

# %% [markdown]
# ## 4.1.4 Start Simple i.e. 1 agent or agentic flow and extend when necessary
#
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 20px;">
# <p style="margin-bottom: 20px; line-height: 1.6;">Less tends to be more sometimes. In my experience (although I know some
# legal tech providers do this) you don't need a multi-agent system for most common legal tech tasks. However, below are some
# thoughts:</p>
#
# <div style="display: flex; margin: 25px 0; gap: 30px;">
#   <div style="flex: 1; background-color: #3a3f45; padding: 20px; border-radius: 6px; border-left: 4px solid #ffd43b;">
#       <h4 style="margin-top: 0; color: #ffd43b;">When to use Single Agent</h4>
#       <ul style="padding-left: 20px;">
#           <li style="margin-bottom: 8px;">Reviewing simple contracts</li>
#           <li style="margin-bottom: 8px;">Initial MVP or prototype</li>
#           <li style="margin-bottom: 8px;">Limited budget</li>
#           <li style="margin-bottom: 8px;">Quick turnaround needed</li>
#           <li>Simpler implementation requirements</li>
#       </ul>
#   </div>
#
#   <div style="flex: 1; background-color: #3a3f45; padding: 20px; border-radius: 6px; border-left: 4px solid #ffd43b;">
#       <h4 style="margin-top: 0; color: #ffd43b;">When to use Multi-Agent</h4>
#       <ul style="padding-left: 20px;">
#           <li style="margin-bottom: 8px;">Complex contract analysis</li>
#           <li style="margin-bottom: 8px;">Need for detailed clause-by-clause review</li>
#           <li style="margin-bottom: 8px;">When different models have specific strengths</li>
#           <li style="margin-bottom: 8px;">When transparency in the reasoning process is important</li>
#           <li>When cost optimization across different steps matters</li>
#       </ul>
#   </div>
# </div>
#
# <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; margin-top: 20px; border-left: 4px solid
# #ffd43b;">
#   <p style="margin: 0;"><b>Legal tech insight:</b> Start with the simplest solution that meets your requirements. In the
# legal domain, reliability and consistency often outweigh the benefits of sophisticated multi-agent architectures.</p>
# </div>
# </div>

# %% [markdown]
# Define a simple agent for doing the Contract Review

# %%
from prompts import get_nda_analysis_prompt

contract_analysis_prompt = get_nda_analysis_prompt()

system_cr, human_cr = contract_analysis_prompt.format_messages(
    schema_str=json.dumps(ContractMetadata.model_json_schema(), indent=2),
    contract_text=sample_nda,
    policy_text=nda_policy,
    chat_history=[],
)

# %%
pprint(system_cr)
# Out:
# SystemMessage(
#     content=(
#         'You are a legal analysis assistant specializing in Non-Disclosure Agreements (NDAs).\n'
#         "Your task is to analyze the provided NDA contract and determine if it complies with the company's NDA policy."
#         '\n'
#         '\n'
#         'Follow these steps in your analysis:\n'
#         '1. Identify key clauses in the NDA (confidentiality obligations, term, exceptions, etc.)\n'
#         "2. Compare each clause against the company's NDA policy requirements\n"
#         '3. Flag any discrepancies or concerning provisions\n'
#         '4. Provide recommendations for negotiation or modification\n'
#         '\n'
#         'Focus on the following key areas:\n'
#         '- Definition of Confidential Information\n'
#         '- Term of confidentiality obligations\n'
#         '- Permitted disclosures/exceptions\n'
#         '- Return/destruction of confidential information\n'
#         '- Governing law and jurisdiction\n'
# ...

# %%
pprint(human_cr)
# Out:
# HumanMessage(
#     content=(
#         'Please analyze this NDA contract against our company policy:\n'
#         '\n'
#         'NDA Contract:\n'
#         '# MUTUAL NON-DISCLOSURE AGREEMENT\n'
#         '\n'
#         'THIS MUTUAL NON-DISCLOSURE AGREEMENT (the "Agreement") is made and entered into as of May 15, 2025 (the "Effe'
#         'ctive Date") by and between:\n'
#         '\n'
#         '**ACME CORPORATION**, a corporation organized and existing under the laws of Delaware, with its principal pla'
#         'ce of business at 123 Main Street, San Francisco, CA 94105 ("ACME")\n'
#         '\n'
#         'and\n'
#         '\n'
#         '**TECH INNOVATIONS INC.**, a corporation organized and existing under the laws of California, with its princi'
#         'pal place of business at 456 Innovation Way, Palo Alto, CA 94301 ("TECH")\n'
#         '\n'
#         '(each a "Party" and collectively the "Parties").\n'
#         '\n'
#         '## 1. PURPOSE\n'
#         '\n'
# ...

# %%
from pydantic_ai import Agent

cr_agent = Agent(
    model='openai:gpt-4.1', 
    system=system_cr,
    human=human_cr,
    temperature=0.7, 
    verbose=True, 
    instrument=True
    )

# %%
review = cr_agent.run_sync(sample_nda)

# %%
from utils import display_agent_review
display_agent_review(review)
# Out:
# ```markdown
# Your **Mutual Non-Disclosure Agreement** is clear, comprehensive, and uses commonly accepted industry standards. Here are considerations, comments, and suggestions you might find helpful (from a lawyerly or business perspective):
#
# ---
#
# ### 1. **Substantive Review – Highlights**
#
# - **Mutual NDA**: The obligations and definitions apply to both parties, reflecting mutual intent.
# - **Clear Purpose**: The "Purpose" is well-defined, which limits the scope of use.
# - **Definition of Confidential Information**: Broad but clearly lists exclusions (good for clarity and to prevent disputes).
# - **Data Privacy**: Inclusion of GDPR and CCPA compliance is current and relevant, especially with cross-jurisdictional issues.
#
# ---
#
# ### 2. **Areas to Double-Check**
#
# #### **A. Execution/Signatures**
# ...

# %% [markdown]
# Let's do a multi-agent approach as well as an example.
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 20px;">
# <h3 style="color: #ffd43b; border-bottom: 1px solid #555; padding-bottom: 10px; margin-bottom: 20px;">Multi-Agent
# Architecture</h3>
#
# <div style="display: flex; justify-content: center; margin-bottom: 30px; background-color: #3a3f45; padding: 20px;
# border-radius: 8px;">
# <div style="display: flex; flex-direction: column; align-items: center; width: 100%;">
# <!-- Flow diagram manually created with HTML/CSS -->
# <div style="display: flex; width: 100%; justify-content: space-around; margin-bottom: 30px;">
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; border: 1px solid #555; text-align:
# center;">Contract Document</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; border: 1px solid #555; text-align:
# center;">Policy Document</div>
# </div>
#
# <div style="display: flex; width: 100%; justify-content: space-around; margin-bottom: 30px;">
#     <div style="background-color: #ffd43b; color: black; padding: 15px; border-radius: 6px; border: 1px solid #555;
# text-align: center; width: 180px;">
#         Extraction Agent<br><small>(GPT-4.1-mini)</small>
#     </div>
# </div>
#
# <div style="display: flex; width: 100%; justify-content: space-around; margin-bottom: 30px;">
#     <div style="background-color: #ff6b6b; color: white; padding: 15px; border-radius: 6px; border: 1px solid #555;
# text-align: center; width: 180px;">
#         Policy Agent<br><small>(GPT-4.1)</small>
#     </div>
# </div>
#
# <div style="display: flex; width: 100%; justify-content: space-around; margin-bottom: 30px;">
#     <div style="background-color: #ffd43b; color: black; padding: 15px; border-radius: 6px; border: 1px solid #555;
# text-align: center; width: 180px;">
#         Suggestion Agent<br><small>(GPT-4.1-mini)</small>
#     </div>
#     <div style="background-color: #ff6b6b; color: white; padding: 15px; border-radius: 6px; border: 1px solid #555;
# text-align: center; width: 180px;">
#         Orchestrator<br><small>(GPT-4.1)</small>
#     </div>
# </div>
#
# <div style="display: flex; width: 100%; justify-content: center; margin-bottom: 10px;">
#     <div style="background-color: #00c08b; color: white; padding: 15px; border-radius: 6px; border: 1px solid #555;
# text-align: center; width: 180px;">
#         Final Report
#     </div>
# </div>
#
# <!-- Arrows would make this more complex, so simplified for clarity -->
# </div>
# </div>
#
# <table style="width: 100%; border-collapse: collapse; margin: 20px 0;">
# <thead>
# <tr style="background-color: #3a3f45; text-align: left;">
#     <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Agent</th>
#     <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Role</th>
#     <th style="padding: 12px 15px; border-bottom: 2px solid #555; color: #ffd43b;">Model</th>
# </tr>
# </thead>
# <tbody>
# <tr style="border-bottom: 1px solid #444;">
#     <td style="padding: 12px 15px; font-weight: bold;">Extraction Agent</td>
#     <td style="padding: 12px 15px;">Identifies key clauses in the NDA</td>
#     <td style="padding: 12px 15px;"><span style="background-color: #ffd43b; color: black; padding: 3px 8px;
# border-radius: 3px;">GPT-4.1-mini</span></td>
# </tr>
# <tr style="border-bottom: 1px solid #444; background-color: #343a40;">
#     <td style="padding: 12px 15px; font-weight: bold;">Policy Agent</td>
#     <td style="padding: 12px 15px;">Analyzes compliance with company policy</td>
#     <td style="padding: 12px 15px;"><span style="background-color: #ff6b6b; color: white; padding: 3px 8px;
# border-radius: 3px;">GPT-4.1</span></td>
# </tr>
# <tr style="border-bottom: 1px solid #444;">
#     <td style="padding: 12px 15px; font-weight: bold;">Suggestion Agent</td>
#     <td style="padding: 12px 15px;">Generates improved clause language</td>
#     <td style="padding: 12px 15px;"><span style="background-color: #ffd43b; color: black; padding: 3px 8px;
# border-radius: 3px;">GPT-4.1-mini</span></td>
# </tr>
# <tr>
#     <td style="padding: 12px 15px; font-weight: bold;">Orchestrator</td>
#     <td style="padding: 12px 15px;">Produces final review and recommendations</td>
#     <td style="padding: 12px 15px;"><span style="background-color: #ff6b6b; color: white; padding: 3px 8px;
# border-radius: 3px;">GPT-4.1</span></td>
# </tr>
# </tbody>
# </table>
#
# <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; margin-top: 20px; border-left: 4px solid
# #ffd43b;">
# <p style="margin: 0;"><b>Workflow:</b> Contract and policy documents flow through specialized agents that perform
# extraction → policy analysis → suggestion generation → final review and recommendations.</p>
# </div>
# </div>

# %%
from agents import review_contract_with_agents, format_multi_agent_results

# Run the multi-agent review
review_result = review_contract_with_agents(complex_nda, nda_policy)

# Display the formatted results
display(format_multi_agent_results(review_result))
# Out:
# Step 1: Extracting key clauses...
#
# ----- EXTRACTED CLAUSES -----
#
# 1. Definitions (Section 1)
#    Importance: 9/10
#    Text: Defines key terms including 'Affiliate', 'Confidential Information', and 'Residual Knowledge' to clarify the scope and nature of information covered b...
#
# 2. Exclusions (Section 2)
#    Importance: 9/10
#    Text: Lists specific categories of information that are excluded from confidentiality obligations, such as information already known, publicly available, in...
#
# 3. Obligations of Non-Disclosure and Non-Use (Section 3)
#    Importance: 10/10
#    Text: Obligates each Party to maintain confidentiality of disclosed information, restricts use to the Business Purpose, controls disclosure to Representativ...
#
# 4. Personal Data Processing (Section 4)
#    Importance: 8/10
#    Text: Mandates compliance with applicable data protection laws when handling personal data within Confidential Information and requires appropriate security...
#
# ...

# %% [markdown]
# ## 4.1.5 Use a tracing solution, you will need it

# %% [markdown]
# ## 4.1.6 Make sure to track costs, Agent loops can be expensive

# %% [markdown]
# ## 4.1.7 Give control to the end-user i.e. HIL or <i>human-in-the-loop</i>

# %% [markdown]
# ## 4.1.8 Always ground your Agent results, end-users in this case lawyers will always fact check

# %% [markdown]
# ## 4.1.9 Prioritize ethical guardrails and explainability for regulatory compliance

# %% [markdown]
# ## 4.1.10 Implement continuous monitoring and feedback‑driven iteration

# %% [markdown]
#  <a id="section5"></a>
# # 5. Conclusions

# %% [markdown]
#  <a id="section6"></a>
# # 6. References

# %% [markdown]
#   <div style="background-color: #2c3033; padding: 15px; border-radius: 6px; margin-top: 30px; margin-bottom: 30px; border-left: 4px solid #ffd43b;">
# <span style="float: right; color: #ffd43b;">© Marcus Elwin, 2025</span>
#   </div>
