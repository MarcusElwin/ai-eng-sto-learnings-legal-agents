# %% [markdown]
# # Learnings from building legal agents @Pocketlaw
# ## AI Engineering Stockholm Meetup `2025-04-23`
#
# <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; margin-bottom: 30px;">
#       <h2 style="text-align: center; margin-bottom: 25px; border-bottom: 2px solid #ffd43b; padding-bottom: 15px;">
#           Table of Content
#       </h2>
#
# <div style="font-size: 18px; line-height: 1.6;">
#     <a href="#section1" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#         <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">1</span>
#         <span>Who am I? <span style="color: #aaa; font-size: 15px;">- Introduction and background</span></span>
#     </a>
#
# <a href="#section2" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">2</span>
#     <span>Who are Pocketlaw? <span style="color: #aaa; font-size: 15px;">- Company overview</span></span>
# </a>
#
# <a href="#section3" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">3</span>
#     <span>AI and Agents in the Legal Domain <span style="color: #aaa; font-size: 15px;">- Current applications</span></span>
# </a>
#
# <a href="#section4" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">4</span>
#     <span>A few learnings from working with Agents in Legal Tech <span style="color: #aaa; font-size: 15px;">- Key insights</span></span>
# </a>
#
# <a href="#section5" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center; margin-bottom: 15px;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">5</span>
#     <span>Conclusions <span style="color: #aaa; font-size: 15px;">- Summary and takeaways</span></span>
# </a>
#
# <a href="#section6" style="color: #ffd43b; text-decoration: none; display: flex; align-items: center;">
#     <span style="background-color: #444; border-radius: 50%; width: 30px; height: 30px; display: inline-flex; justify-content: center; align-items: center; margin-right: 15px;">6</span>
#     <span>References <span style="color: #aaa; font-size: 15px;">- Sources and citations</span></span>
# </a>
# </div>
#   </div>
#
# Let's start shall we.

# %% [markdown]
#  <a id="section1"></a>
# # 1. Who am I? 📖
#   <div style="background-color: #2c3033; color: white; padding: 25px; border-radius: 10px; max-width: 1000px;">
#
#   <h2 style="font-size: 28px; margin-bottom: 20px;"><span style="color: yellow;">Hi</span> 👋🏽 I'm Marcus!</h2>
#
#    <h2 style="font-size: 22px; margin-bottom: 20px;"><span style="color: yellow;">Lead AI Engineer @Pocketlaw</span> </h2>
#
#   <div style="display: flex; align-items: flex-start; max-width: 1000px; margin-bottom: 30px;">
#       <div style="flex: 1; padding-right: 40px;">
#           <ul style="padding-left: 20px;">
#               <li style="margin-bottom: 15px;">Background in Computer Science & Machine Learning (KTH)</li>
#               <li style="margin-bottom: 15px;">7+ years of AI & ML experience in various roles and industries</li>
#               <li style="margin-bottom: 15px;">Worked with DS, ML, DL, now GenAI and a pit of product management</li>
#               <li style="margin-bottom: 15px;">Previously at Tink, ICA Gruppen AB & Nasdaq</li>
#               <li>Joined Pocketlaw Nov 23'</li>
#           </ul>
#       </div>
#       <div style="width: 300px; flex-shrink: 0;">
#           <img src="images/animeME.png" width="100%" />
#       </div>
#   </div>
#
#   <div style="display: flex; gap: 40px;">
#       <div style="text-align: center;">
#           <img src="images/blog_qr.png" width="150px" />
#           <p><strong>Personal Blog</strong></p>
#       </div>
#       <div style="text-align: center;">
#           <img src="images/linkedin_qr.png" width="150px" />
#           <p><strong>LinkedIn</strong></p>
#       </div>
#   </div>
#   </div>

# %% [markdown]
#  <a id="section2"></a>
# # 2. Who are Pocketlaw?

# %% [markdown]
# __TODO__

# %% [markdown]
#  <a id="section3"></a>
# # 3. AI and Agents in the Legal Domain

# %% [markdown]
# ## 3.1 AI in Legal domain - historical timeline
# To set the stage, let's start of with some key historical events for AI in the Legal domain:
#
# <div style="width: 100%; padding: 20px; background-color: #2c3033; color: white;">
# <h1 style="text-align: center; margin-bottom: 30px; color: white;">AI in Legal Domain - Historical Timeline</h1>
#
# <div style="max-width: 800px; margin: 0 auto; position: relative; min-height: 700px;">
#     <!-- Center line with fixed height -->
#     <div style="position: absolute; width: 4px; background-color: #555; height: 100%; left: 50%; margin-left: -2px;"></div>
#
# <!-- 1950s-1960s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1950s-1960s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>1950 - Turing test<sup>1</sup></li>
#                 <li>1956 - Dartmouth Conference<sup>2</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 1970s-1980s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1970s-1980s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>1970s: Expert systems in Law<sup>3</sup></li>
#             <li>1980: MYCIN inspires legal AI<sup>4</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
#
# <!-- 1990s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">1990s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>1990s: NLP in legal document analysis<sup>5</sup></li>
#                 <li>1990s: Case based reasoning systems like HYPO<sup>6</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 2000s -->
# <div style="position: relative; margin-bottom: 80px; height: 80px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2000s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>2000s: e-discovery introduced<sup>7</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
#
# <!-- 2010s -->
# <div style="position: relative; margin-bottom: 80px; height: 120px;">
#     <!-- Content box on left -->
#     <div style="position: absolute; width: 45%; left: 0; text-align: right;">
#         <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2010s</div>
#         <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             <ul style="list-style-position: inside; padding-left: 0;">
#                 <li>2011: IBM Watson wins Jeopardy<sup>8</sup></li>
#                 <li>2012: Ross Intelligence<sup>9</sup></li>
#                 <li>2016: Kira Systems<sup>10</sup></li>
#                 <li>2018: LawGeex outperforms human lawyers<sup>11</sup></li>
#                 <li>2018: Lex Machina & Premonition<sup>12</sup></li>
#             </ul>
#         </div>
#     </div>
#
# <!-- Circle marker in the center -->
# <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
# </div>
#
# <!-- 2020s -->
# <div style="position: relative; margin-bottom: 40px; height: 120px;">
#     <!-- Circle marker in the center -->
#     <div style="position: absolute; width: 20px; height: 20px; background-color: #2c3033; border: 4px solid #ffd43b; border-radius: 50%; left: 50%; top: 15px; transform: translateX(-50%); z-index: 2;"></div>
#
# <!-- Content box on right -->
# <div style="position: absolute; width: 45%; right: 0;">
#     <div style="display: inline-block; background: #444; color: white; padding: 8px 16px; border-radius: 4px; font-weight: bold; margin-bottom: 10px;">2020s</div>
#     <div style="background-color: #3a3f45; padding: 15px; border-radius: 6px; box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#         <ul style="list-style-position: inside; padding-left: 0;">
#             <li>2020: GPT-3 released<sup>13</sup></li>
#             <li>2020: Pocketlaw founded<sup>14</sup></li>
#             <li>2022: ChatGPT released with legal Chatbots to follow<sup>15</sup></li>
#             <li>2023: Pocketlaw does AI pivot<sup>16</sup></li>
#             <li>2024+: AI in legal tech thrives with plethora of actors<sup>17</sup></li>
#         </ul>
#     </div>
# </div>
# </div>
# </div>
#
# <p style="text-align: center; margin-top: 30px; color: #aaa; font-size: 0.8rem;">Numbers 1-17 represent citations/references to source materials</p>
# </div>

# %% [markdown]
# ## 3.2 Examples of Agentic use cases for Legal

# %% [markdown]
# ### AI  agent Overview
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">AI Agent Overview</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Simplified model of AI Agent, plenty out there
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Observe Environment
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Take actions to achive goals
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Loop until goals are achived
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - Overview.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ### AI Agent Example Use Case #1: Contract Review
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">Example of Contract Review Agent</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       User ask for feedback on a contract e.g. NDA
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Agent has memory from previous interactions
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans: clause analysis
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Uses various tools
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Recommend amendments to contract
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - CR.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ### AI Agent Example Use Case #2: Legal Research
# <div style="background-color: #2c3033; color: white; padding: 30px; border-radius: 10px; max-width: 1000px; box-shadow: 0 4px 8px rgba(0,0,0,0.2);">
#       <div style="display: flex; align-items: center; gap: 40px;">
#           <div style="flex: 1;">
#               <h3 style="color: #ffd43b; margin-bottom: 20px; border-bottom: 1px solid #555; padding-bottom: 10px;">Example of Legal Research Agent</h3>
#               <ul style="padding-left: 25px; list-style-type: none;">
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       User ask for particular research query
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Agent has memory from previous interactions
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Reason and plans: clause analysis
#                   </li>
#                   <li style="margin-bottom: 15px; position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Uses various tools i.e. internet or legal databases (similar to deep research mode)
#                   </li>
#                   <li style="position: relative;">
#                       <span style="position: absolute; left: -25px; color: #ffd43b;">▶</span>
#                       Presents findigns
#                   </li>
#               </ul>
#           </div>
#           <div style="flex-shrink: 0; width: 500px;">
#               <img src="images/AI agent - LS.png" width="100%" style="border-radius: 5px; box-shadow: 0 3px 6px rgba(0,0,0,0.3);" />
#           </div>
#       </div>
#   </div>

# %% [markdown]
# ## 3.3 Why are Agents and Agentic Workflows of interest for Legal Tech?

# %% [markdown]
# __TODO__

# %% [markdown]
#  <a id="section4"></a>
# # 4. A few learnings from working with Agents in Legal Tech 🤖

# %% [markdown]
#  <a id="section5"></a>
# # 5. Conclusions

# %% [markdown]
#  <a id="section6"></a>
# # 6. References
